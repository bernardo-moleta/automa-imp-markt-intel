# %%
import pandas as pd

# %%
def baixar_volumes_siacesp(caminho: str):
    """Carrega volumes do SIACESP (arquivo Excel)."""
    df = pd.read_excel(caminho)
    df["Z_PERÍODO"] = pd.to_datetime(df["Z_PERÍODO"], errors="coerce")
    df["VOLUME"] = pd.to_numeric(df["VOLUME"], errors="coerce").fillna(0)

# %%
vomlumes = baixar_volumes_siacesp(caminho=r'C:\Users\BERNARDOJULIODEALMEI\BRFERTIL S.A\Importação - INTELIGÊNCIA DE MERCADO\Bases_Excel\BI_Importacao Siacesp.xlsx')

# %%
print(vomlumes)
# Out:
# None
